# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score

# %%
matches = pd.read_csv("matches_copy.csv", index_col=0)

# %%
matches["Date"] = pd.to_datetime(matches["Date"])
matches["Venue_Code"] = matches["Venue"].astype("category").cat.codes
matches["Opp_Code"] = matches["Opponent"].astype("category").cat.codes
matches["Hour"] = matches["Time"].str.replace(":.+", "", regex=True).astype("int")
matches["Day_Code"] = matches["Date"].dt.dayofweek

# %%
matches["Target"] = (matches["Result"] == "W").astype("int")

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["Date"] < '2024-01-01']
test = matches[matches["Date"] > '2024-01-01']
predictors = ["Venue_Code", "Opp_Code", "Hour", "Day_Code"]
rf.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
precision_score(test["Target"], preds)
# Out:
# 0.39473684210526316

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("Date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["GF", "GA", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]
new_cols = [f"{c}_rolling" for c in cols]
# Out:
#          Date   Time            Comp         Round  Day Venue Result   GF  \
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  6.0
# 6  2022-09-03  17:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2022-09-17  12:30  Premier League   Matchweek 8  Sat  Away      W  3.0
# 10 2022-10-02  14:00  Premier League   Matchweek 9  Sun  Home      W  6.0
# 12 2022-10-08  15:00  Premier League  Matchweek 10  Sat  Home      W  4.0
# 14 2022-10-16  16:30  Premier League  Matchweek 11  Sun  Away      L  0.0
# 15 2022-10-22  15:00  Premier League  Matchweek 13  Sat  Home      W  3.0
# 17 2022-10-29  12:30  Premier League  Matchweek 14  Sat  Away      W  1.0
# 19 2022-11-05  15:00  Premier League  Matchweek 15  Sat  Home      W  2.0
# 21 2022-11-12  12:30  Premier League  Matchweek 16  Sat  Home      L  1.0
# 23 2022-12-28  20:00  Premier League  Matchweek 17  Wed  Away      W  3.0
# 24 2022-12-31  15:00  Premier League  Matchweek 18  Sat  Home      D  1.0
# 25 2023-01-05  20:00  Premier League  Matchweek 19  Thu  Away      W  1.0
# 28 2023-01-14  12:30  Premier League  Matchweek 20  Sat  Away      L  1.0
# 29 2023-01-19  20:00  Premier League   Matchweek 7  Thu  Home      W  4.0
# 30 2023-01-22  14:00  Premier League  Matchweek 21  Sun  Home      W  3.0
# 32 2023-02-05  16:30  Premier League  Matchweek 22  Sun  Away      L  0.0
# 33 2023-02-12  16:30  Premier League  Matchweek 23  Sun  Home      W  3.0
# 34 2023-02-15  19:30  Premier League  Matchweek 12  Wed  Away      W  3.0
# 35 2023-02-18  15:00  Premier League  Matchweek 24  Sat  Away      D  1.0
# 37 2023-02-25  17:30  Premier League  Matchweek 25  Sat  Away      W  4.0
# 39 2023-03-04  12:30  Premier League  Matchweek 26  Sat  Home      W  2.0
# 40 2023-03-11  17:30  Premier League  Matchweek 27  Sat  Away      W  1.0
# 43 2023-04-01  12:30  Premier League  Matchweek 29  Sat  Home      W  4.0
# 44 2023-04-08  17:30  Premier League  Matchweek 30  Sat  Away      W  4.0
# 46 2023-04-15  17:30  Premier League  Matchweek 31  Sat  Home      W  3.0
# 49 2023-04-26  20:00  Premier League  Matchweek 33  Wed  Home      W  4.0
# 50 2023-04-30  14:00  Premier League  Matchweek 34  Sun  Away      W  2.0
# 51 2023-05-03  20:00  Premier League  Matchweek 28  Wed  Home      W  3.0
# 52 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W  2.0
# 54 2023-05-14  14:00  Premier League  Matchweek 36  Sun  Away      W  3.0
# 56 2023-05-21  16:00  Premier League  Matchweek 37  Sun  Home      W  1.0
# 57 2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D  1.0
# 58 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L  0.0
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W  3.0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W  1.0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2.0
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5.0
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3.0
# 8  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 10 2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L  1.0
# 12 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L  0.0
# 13 2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W  2.0
# 15 2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W  3.0
# 16 2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W  6.0
# 18 2023-11-12  16:30  Premier League  Matchweek 12  Sun  Away      D  4.0
# 19 2023-11-25  12:30  Premier League  Matchweek 13  Sat  Home      D  1.0
# 21 2023-12-03  16:30  Premier League  Matchweek 14  Sun  Home      D  3.0
# 22 2023-12-06  20:15  Premier League  Matchweek 15  Wed  Away      L  0.0
# 23 2023-12-10  14:00  Premier League  Matchweek 16  Sun  Away      W  2.0
# 25 2023-12-16  15:00  Premier League  Matchweek 17  Sat  Home      D  2.0
# 26 2023-12-27  20:15  Premier League  Matchweek 19  Wed  Away      W  3.0
# 27 2023-12-30  15:00  Premier League  Matchweek 20  Sat  Home      W  2.0
# 29 2024-01-13  17:30  Premier League  Matchweek 21  Sat  Away      W  3.0
# 31 2024-01-31  19:30  Premier League  Matchweek 22  Wed  Home      W  3.0
# 32 2024-02-05  20:00  Premier League  Matchweek 23  Mon  Away      W  3.0
# 33 2024-02-10  12:30  Premier League  Matchweek 24  Sat  Home      W  2.0
# 35 2024-02-17  17:30  Premier League  Matchweek 25  Sat  Home      D  1.0
# 36 2024-02-20  19:30  Premier League  Matchweek 18  Tue  Home      W  1.0
#
#      GA         Opponent  ...  Day_Code  Target  GF_rolling  GA_rolling  \
# 4   2.0   Crystal Palace  ...         5       1    3.000000    1.000000
# 5   0.0  Nott'ham Forest  ...         2       1    3.666667    1.666667
# 6   1.0      Aston Villa  ...         5       0    4.333333    1.666667
# 9   0.0           Wolves  ...         5       1    3.666667    1.000000
# 10  3.0   Manchester Utd  ...         6       1    3.333333    0.333333
# 12  0.0      Southampton  ...         5       1    3.333333    1.333333
# 14  1.0        Liverpool  ...         6       0    4.333333    1.000000
# 15  1.0         Brighton  ...         5       1    3.333333    1.333333
# 17  0.0   Leicester City  ...         5       1    2.333333    0.666667
# 19  1.0           Fulham  ...         5       1    1.333333    0.666667
# 21  2.0        Brentford  ...         5       0    2.000000    0.666667
# 23  1.0     Leeds United  ...         2       1    1.333333    1.000000
# 24  1.0          Everton  ...         5       0    2.000000    1.333333
# 25  0.0          Chelsea  ...         3       1    1.666667    1.333333
# 28  2.0   Manchester Utd  ...         5       0    1.666667    0.666667
# 29  2.0        Tottenham  ...         3       1    1.000000    1.000000
# 30  0.0           Wolves  ...         6       1    2.000000    1.333333
# 32  1.0        Tottenham  ...         6       0    2.666667    1.333333
# 33  1.0      Aston Villa  ...         6       1    2.333333    1.000000
# 34  1.0          Arsenal  ...         2       1    2.000000    0.666667
# 35  1.0  Nott'ham Forest  ...         5       0    2.000000    1.000000
# 37  1.0      Bournemouth  ...         5       1    2.333333    1.000000
# 39  0.0    Newcastle Utd  ...         5       1    2.666667    1.000000
# 40  0.0   Crystal Palace  ...         5       1    2.333333    0.666667
# 43  1.0        Liverpool  ...         5       1    2.333333    0.333333
# 44  1.0      Southampton  ...         5       1    2.333333    0.333333
# 46  1.0   Leicester City  ...         5       1    3.000000    0.666667
# 49  1.0          Arsenal  ...         2       1    3.666667    1.000000
# 50  1.0           Fulham  ...         6       1    3.666667    1.000000
# 51  0.0         West Ham  ...         2       1    3.000000    1.000000
# 52  1.0     Leeds United  ...         5       1    3.000000    0.666667
# 54  0.0          Everton  ...         6       1    2.333333    0.666667
# 56  0.0          Chelsea  ...         6       1    2.666667    0.333333
# 57  1.0         Brighton  ...         2       0    2.000000    0.333333
# 58  1.0        Brentford  ...         6       0    1.666667    0.333333
# 1   0.0          Burnley  ...         4       1    0.666667    0.666667
# 3   0.0    Newcastle Utd  ...         5       1    1.333333    0.666667
# 4   1.0    Sheffield Utd  ...         6       1    1.333333    0.333333
# 5   1.0           Fulham  ...         5       1    2.000000    0.333333
# 6   1.0         West Ham  ...         5       1    2.666667    0.666667
# 8   0.0  Nott'ham Forest  ...         5       1    3.333333    1.000000
# 10  2.0           Wolves  ...         5       0    3.333333    0.666667
# 12  1.0          Arsenal  ...         6       0    2.000000    1.000000
# 13  1.0         Brighton  ...         5       1    1.000000    1.000000
# 15  0.0   Manchester Utd  ...         6       1    1.000000    1.333333
# 16  1.0      Bournemouth  ...         5       1    1.666667    0.666667
# 54  14.666667    7.000000    16.366667   0.666667    0.333333       0.666667
# 56  14.000000    5.666667    18.100000   1.333333    0.000000       0.333333
# 57  13.666667    4.000000    18.933333   1.333333    0.000000       0.333333
# 58  12.333333    3.333333    17.333333   0.666667    0.000000       0.000000
# 1   15.000000    2.666667    16.500000   0.000000    0.000000       0.000000
# 3   15.666667    4.666667    14.866667   0.000000    0.000000       0.000000
# 4   16.000000    4.666667    16.200000   0.000000    0.000000       0.000000
# 5   20.000000    7.000000    16.366667   0.666667    0.000000       0.333333
# 6   16.333333    5.666667    16.666667   0.666667    0.333333       0.666667
# 8   21.333333    8.666667    16.166667   1.000000    0.333333       0.666667
# 10  14.000000    7.000000    16.133333   1.000000    0.333333       0.333333
# 12  19.666667    8.333333    17.633333   1.333333    0.000000       0.000000
# 13  11.333333    4.000000    17.133333   1.000000    0.000000       0.000000
# 15  12.333333    4.333333    17.666667   0.666667    0.000000       0.000000
# 16  11.333333    4.666667    16.966667   1.000000    0.333333       0.333333
# 18  17.000000    7.333333    17.466667   1.000000    0.333333       0.333333
# 19  18.333333    8.666667    16.733333   1.000000    0.666667       0.666667
# 21  17.000000    7.333333    16.433333   0.666667    0.333333       0.333333
# 22  15.666667    6.000000    15.433333   0.666667    0.333333       0.333333
# 23  11.666667    3.666667    12.366667   0.333333    0.000000       0.000000
# 25  12.333333    4.000000    13.166667   0.333333    0.000000       0.000000
# 26  13.000000    5.666667    14.766667   0.333333    0.000000       0.000000
# 27  19.666667    7.666667    18.800000   0.666667    0.333333       0.333333
# 29  19.666667    7.000000    18.366667   0.333333    0.333333       0.333333
# 31  22.333333    7.666667    18.733333   1.000000    0.333333       0.333333
# 32  19.666667    6.333333    17.500000   1.000000    0.000000       0.000000
# 33  22.000000   10.000000    18.100000   1.000000    0.000000       0.000000
# 35  19.333333    7.333333    17.466667   0.333333    0.000000       0.000000
# 36  25.000000    7.666667    17.500000   0.333333    0.000000       0.000000
#
# [60 rows x 40 columns]

# %%
matches_rolling = matches.groupby("Team").apply(lambda x: rolling_averages(x, cols, new_cols), include_groups=False)
matches_rolling = matches_rolling.reset_index()
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling = matches_rolling.drop("level_1", axis=1)

# %%
def make_predictions(data, predictors):
    train = data[data["Date"] < '2024-01-01']
    test = data[data["Date"] > '2024-01-01']
    rf.fit(train[predictors], train["Target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["Target"], predicted=preds), index=test.index)
    error = precision_score(test["Target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)
error
# Out:
# 0.6

# %%
matches_rolling.dtypes
combined = combined.merge(matches_rolling[["Date", "Team", "Opponent", "Result"]], left_index=True, right_index=True)

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", 
              "Manchester United": "Manchester Utd", 
              "Newcastle United": "Newcastle Utd", 
              "Tottenham Hotspur": "Tottenham", 
              "West Ham United": "West Ham", 
              "Wolverhampton Wanderers": "Wolves",
              "Nottingham Forest": "Nott'ham Forest",
              "Sheffield United": "Sheffield Utd"
             } 

mapping = MissingDict(**map_values)
combined["New_Team"] = combined["Team"].map(mapping)
merged = combined.merge(combined, left_on=["Date", "New_Team"], right_on=["Date", "Opponent"])
merged
# Out:
#      actual_x  predicted_x   Date_x_x                 Team_x_x  \
# 0           1            1 2024-01-20                  Arsenal
# 1           1            1 2024-01-30                  Arsenal
# 2           1            1 2024-02-04                  Arsenal
# 3           1            0 2024-02-11                  Arsenal
# 4           1            0 2024-02-17                  Arsenal
# ..        ...          ...        ...                      ...
# 101         0            1 2024-01-22  Wolverhampton Wanderers
# 102         0            0 2024-02-01  Wolverhampton Wanderers
# 103         1            0 2024-02-04  Wolverhampton Wanderers
# 104         0            0 2024-02-10  Wolverhampton Wanderers
# 105         1            0 2024-02-17  Wolverhampton Wanderers
#
#         Opponent_x_x Result_x_x   Date_y_x                 Team_y_x  \
# 0     Crystal Palace          W 2024-01-20                  Arsenal
# 1    Nott'ham Forest          W 2024-01-30                  Arsenal
# 2          Liverpool          W 2024-02-04                  Arsenal
# 3           West Ham          W 2024-02-11                  Arsenal
# 4            Burnley          W 2024-02-17                  Arsenal
# ..               ...        ...        ...                      ...
# 101         Brighton          D 2024-01-22  Wolverhampton Wanderers
# 102   Manchester Utd          L 2024-02-01  Wolverhampton Wanderers
# 103          Chelsea          W 2024-02-04  Wolverhampton Wanderers
# 104        Brentford          L 2024-02-10  Wolverhampton Wanderers
# 105        Tottenham          W 2024-02-17  Wolverhampton Wanderers
#
#         Opponent_y_x Result_y_x  ... Opponent_x_y Result_x_y   Date_y_y  \
# 0     Crystal Palace          W  ...      Arsenal          L 2024-01-20
# 1    Nott'ham Forest          W  ...      Arsenal          L 2024-01-30
# 2          Liverpool          W  ...      Arsenal          L 2024-02-04
# 3           West Ham          W  ...      Arsenal          L 2024-02-11
# 4            Burnley          W  ...      Arsenal          L 2024-02-17
# ..               ...        ...  ...          ...        ...        ...
# 101         Brighton          D  ...       Wolves          D 2024-01-22
# 102   Manchester Utd          L  ...       Wolves          W 2024-02-01
# 103          Chelsea          W  ...       Wolves          L 2024-02-04
# 104        Brentford          L  ...       Wolves          W 2024-02-10
# 105        Tottenham          W  ...       Wolves          L 2024-02-17
#
#                      Team_y_y Opponent_y_y  Result_y_y  \
# 0              Crystal Palace      Arsenal           L
# 1           Nottingham Forest      Arsenal           L
# 2                   Liverpool      Arsenal           L
# 3             West Ham United      Arsenal           L
# 4                     Burnley      Arsenal           L
# ..                        ...          ...         ...
# 101  Brighton and Hove Albion       Wolves           D
# 102         Manchester United       Wolves           W
# 103                   Chelsea       Wolves           L
# 104                 Brentford       Wolves           W
# 105         Tottenham Hotspur       Wolves           L
#
#                        Team_y Opponent_y Result_y       New_Team_y
# 0              Crystal Palace    Arsenal        L   Crystal Palace
# 1           Nottingham Forest    Arsenal        L  Nott'ham Forest
# 2                   Liverpool    Arsenal        L        Liverpool
# 3             West Ham United    Arsenal        L         West Ham
# 4                     Burnley    Arsenal        L          Burnley
# ..                        ...        ...      ...              ...
# 101  Brighton and Hove Albion     Wolves        D         Brighton
# 102         Manchester United     Wolves        W   Manchester Utd
# 103                   Chelsea     Wolves        L          Chelsea
# 104                 Brentford     Wolves        W        Brentford
# 105         Tottenham Hotspur     Wolves        L        Tottenham
#
# [106 rows x 29 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    14
# 0     7
# Name: count, dtype: int64
